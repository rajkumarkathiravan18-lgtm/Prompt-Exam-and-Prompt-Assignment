# %% [markdown]
# # 7-Day Weight Gain Meal Plan — Chat Input & Output
#
# This notebook contains the **input prompt** and the **assistant output** from the chat.

# %% [markdown]
# # Input
#
# ## R — Role
#
# Act as a qualified sports nutritionist and diet planner specializing in **healthy weight gain, muscle building, and practical meal planning for working professionals**. Create plans using commonly available Indian foods, with a focus on sustainable calorie surplus, adequate protein, balanced nutrition, affordability, and meal-prep convenience.
#
# ## T — Task
#
# Create a **7-day meal plan for healthy weight gain and muscle growth**.
#
# The plan should:
#
# - Provide a moderate calorie surplus suitable for gradual weight gain.
# - Prioritize sufficient daily protein to support strength training and muscle growth.
# - Include breakfast, mid-morning snack, lunch, evening/pre-workout snack, dinner, and bedtime snack where appropriate.
# - Use practical meals that can be prepared at home or carried to work.
# - Include both vegetarian and non-vegetarian options according to the user's dietary schedule.
# - Give **exact approximate quantities/serving sizes** for each food.
# - Provide estimated **calories, protein, carbohydrates, and fats** for each meal and daily total.
# - Include affordable Indian food options and avoid unnecessarily expensive supplements or exotic foods.
# - Provide suitable pre-workout and post-workout meals.
# - Include hydration guidance.
# - Include a weekly grocery list with approximate quantities.
# - Include simple meal-preparation/batch-cooking suggestions for a working professional.
# - Clearly identify meals that can be prepared the previous night or packed for work.
# - Suggest practical substitutions when a particular ingredient is unavailable.
# - Avoid recommending unsafe or extreme weight-gain strategies.
#
# ## C — Context
#
# Use the following user's details:
#
# - Age: **28**
# - Sex: **Male**
# - Height: **5'10" (178 cm)**
# - Current weight: **67 kg**
# - Target weight: **75 kg**
# - Activity level: **Moderate**
# - Strength training: **Yes**
# - Diet: **Non-vegetarian**
# - Non-vegetarian-free days: **Sunday, Monday, Wednesday, Thursday**
# - Allergies/intolerances: **None**
# - Foods disliked: **Nothing specific**
# - Monthly food budget: **₹12,000**
# - Location/food availability: **Tamil Nadu, India**
# - Lifestyle: **Working professional**
#
# Design the plan primarily around affordable and easily available Indian/Tamil Nadu foods such as rice, idli, dosa, chapati, eggs, chicken, fish, dal, sambar, curd, milk, paneer, soy/chunks, peanuts, banana, oats, vegetables, fruits, and other practical local foods.
#
# The goal is to move from **67 kg toward 75 kg** while minimizing unnecessary fat gain and supporting strength-training performance.
#
# Do not assume that gaining 8 kg should happen within 7 days. Explain a realistic expected rate of weight gain and how the meal plan should be adjusted based on weekly weight changes.
#
# ## F — Few Shots
#
# ### Example 1 — Daily meal structure
#
# **Breakfast:** 4 idlis + sambar + 3 eggs + banana
# **Mid-morning:** Milk + peanuts
# **Lunch:** Rice + dal/sambar + vegetables + curd + protein source
# **Pre-workout:** Banana + peanut butter
# **Post-workout:** Milk/curd + protein-rich food
# **Dinner:** Rice/chapati + protein source + vegetables
# **Before bed:** Milk/curd if required
#
# The exact foods and quantities should be adjusted based on calorie and protein requirements rather than blindly copying this example.
#
# ### Example 2 — Vegetarian day
#
# Use combinations such as:
#
# - Oats + milk + banana + peanuts
# - Idli/dosa + sambar
# - Rice + dal + vegetables + curd
# - Paneer/tofu/soy chunks
# - Chapati + dal + vegetables
# - Milk + banana + nuts
#
# ### Example 3 — Non-vegetarian day
#
# Use affordable protein sources such as:
#
# - Eggs
# - Chicken
# - Fish
# - Curd/milk
# - Dal and legumes
#
# Do not rely heavily on expensive protein supplements unless there is a genuine nutritional reason.
#
# ## R — Response
#
# Present the answer in the following structure:
#
# ### 1. Goal & Nutrition Targets
#
# - Current weight
# - Target weight
# - Estimated maintenance calories
# - Recommended calorie target
# - Daily protein target
# - Recommended carbohydrate and fat range
# - Realistic weekly weight-gain target
#
# ### 2. 7-Day Meal Plan
#
# Create a table with:
#
# | DayMealFoodsQuantityCaloriesProtein |
# | ----------------------------------- |
#
# Include:
#
# - Breakfast
# - Mid-morning snack
# - Lunch
# - Evening/pre-workout
# - Post-workout
# - Dinner
# - Bedtime snack where appropriate
#
# Clearly mark **vegetarian days** and **non-vegetarian days**.
#
# ### 3. Daily Summary
#
# For each day provide:
#
# - Total calories
# - Total protein
# - Total carbohydrates
# - Total fats
# - Approximate meal-preparation time
#
# ### 4. Weekly Grocery List
#
# Divide into:
#
# - Rice/grains
# - Protein sources
# - Dairy
# - Fruits
# - Vegetables
# - Nuts/seeds
# - Other essentials
#
# Give approximate quantities required for one week and an estimated cost in **₹**.
#
# ### 5. Meal Prep Strategy for a Working Professional
#
# Explain:
#
# - What to prepare on Sunday
# - What can be batch cooked
# - What can be packed for work
# - How to store meals safely
# - Quick 10–15 minute meal options
# - What to do when there is no time to cook
#
# ### 6. Workout Nutrition
#
# Give practical:
#
# - Pre-workout meal options
# - Post-workout meal options
# - Timing recommendations
# - Hydration guidance
#
# ### 7. Weight Tracking & Adjustments
#
# Explain how to:
#
# - Track body weight correctly
# - Calculate weekly average weight
# - Determine whether calorie intake is sufficient
# - Increase calories if weight is not increasing
# - Reduce calories if weight is increasing too quickly
#
# Give a simple adjustment rule, such as how many calories to add/remove after observing the trend for 2–3 weeks.
#
# ### 8. Budget Check
#
# Show whether the proposed plan realistically fits within the **₹12,000/month food budget**.
#
# If it does not, identify the expensive items and provide cheaper alternatives.
#
# ### 9. Important Notes
#
# Clearly state that calorie and macro values are estimates because actual nutritional values vary by food brand, cooking method, portion size, and preparation.
#
# Do not give medical diagnoses or claim that the meal plan is a substitute for individualized medical or clinical nutrition advice.

# %% [markdown]
# # Output
#
# Below is a **practical 7-day Tamil Nadu–friendly weight-gain plan** built around your 67 kg body weight, strength training, vegetarian days, and ₹12,000/month budget.
#
# One important correction: **₹12,000/month is a tight budget for a high-protein diet, but it is achievable if you rely heavily on rice, dal, soy chunks, peanuts, milk/curd, eggs, and moderate amounts of chicken/fish rather than paneer, whey, or expensive nuts.**
#
# # 1. Goal & Nutrition Targets
#
# | Target | Approximate value |
# |---|---:|
# | Current weight | **67 kg** |
# | Target weight | **75 kg** |
# | Height | **178 cm** |
# | Estimated BMR | ~1,630 kcal/day |
# | Estimated maintenance | ~2,500 kcal/day |
# | Starting calorie target | **2,750–2,850 kcal/day** |
# | Protein target | **125–140 g/day** |
# | Carbohydrates | **350–400 g/day** |
# | Fat | **75–90 g/day** |
# | Target weight gain | **~0.2–0.4 kg/week** |
#
# Your estimated maintenance is only an estimate. Your actual maintenance could be several hundred calories higher or lower depending on your job activity, steps, training volume and metabolism.
#
# ### How long to reach 75 kg?
#
# Don't try to force it.
#
# A sensible rate is approximately **0.2–0.4 kg/week**, meaning gaining 8 kg could realistically take roughly **5–9 months**.
#
# If your weight shoots up by 0.7–1 kg every week, you're probably accumulating more fat than necessary.
#
# # 2. 7-Day Meal Plan
#
# **Assumption:** workout is in the evening.
# **Rice quantities below are cooked weights.**
# **Dal/sambar quantities refer to prepared food.**
#
# ## Day 1 — Sunday 🟢 Vegetarian
#
# | Meal | Foods & quantity | kcal | Protein | Carbs | Fat |
# |---|---|---:|---:|---:|---:|
# | Breakfast | 4 idlis + 250 g sambar + 1 banana + 250 ml milk | 650 | 25 g | 105 g | 13 g |
# | Mid-morning | 30 g peanuts + 200 ml milk | 285 | 13 g | 17 g | 19 g |
# | Lunch | 300 g rice + 200 g dal/sambar + 150 g vegetables + 150 g curd + 10 g oil | 760 | 27 g | 118 g | 20 g |
# | Pre-workout | 1 banana + 40 g roasted peanuts | 330 | 9 g | 38 g | 17 g |
# | Post-workout | 300 ml milk + 50 g roasted chana | 315 | 17 g | 40 g | 9 g |
# | Dinner | 3 chapatis + 50 g dry soy chunks cooked as curry + 150 g vegetables + 150 g curd | 610 | 34 g | 83 g | 15 g |
# | **Total** | | **~2,950** | **~125 g** | **~401 g** | **~93 g** |
#
# ## Day 2 — Monday 🟢 Vegetarian
#
# | Meal | Foods & quantity | kcal | Protein | Carbs | Fat |
# |---|---|---:|---:|---:|---:|
# | Breakfast | 80 g oats + 300 ml milk + banana + 20 g peanuts | 620 | 25 g | 91 g | 20 g |
# | Mid-morning | 200 g curd + 30 g roasted chana | 235 | 12 g | 28 g | 7 g |
# | Lunch | 300 g rice + 200 g sambar + 100 g beans/carrot + 150 g curd + 10 g oil | 700 | 23 g | 110 g | 19 g |
# | Pre-workout | 2 bananas + 20 g peanuts | 290 | 6 g | 52 g | 10 g |
# | Post-workout | 300 ml milk + 40 g roasted chana | 290 | 16 g | 38 g | 8 g |
# | Dinner | 3 dosa + 250 g sambar + 100 g soy-chunk curry | 660 | 32 g | 95 g | 17 g |
# | **Total** | | **~2,795** | **~114 g** | **~414 g** | **~81 g** |
#
# Add **100 g extra curd + 25 g soy chunks** if needed, bringing the day to approximately **2,930 kcal / 127 g protein**.
#
# ## Day 3 — Tuesday 🔴 Non-Vegetarian
#
# | Meal | Foods & quantity | kcal | Protein | Carbs | Fat |
# |---|---|---:|---:|---:|---:|
# | Breakfast | 3 dosa + 3 eggs + 200 g sambar + banana | 690 | 30 g | 91 g | 23 g |
# | Mid-morning | 250 ml milk + 30 g peanuts | 325 | 14 g | 20 g | 21 g |
# | Lunch | 300 g rice + 150 g chicken curry + 150 g vegetables + 150 g curd | 790 | 48 g | 105 g | 21 g |
# | Pre-workout | Banana + 2 slices bread + 15 g peanut butter | 320 | 9 g | 51 g | 10 g |
# | Post-workout | 300 ml milk + 2 boiled eggs | 275 | 20 g | 15 g | 15 g |
# | Dinner | 3 chapatis + 100 g chicken + 150 g vegetables + 100 g curd | 570 | 39 g | 65 g | 15 g |
# | **Total** | | **~2,970** | **~160 g** | **~347 g** | **~105 g** |
#
# ## Day 4 — Wednesday 🟢 Vegetarian
#
# | Meal | Foods & quantity | kcal | Protein | Carbs | Fat |
# |---|---|---:|---:|---:|---:|
# | Breakfast | 4 idlis + 250 g sambar + 250 ml milk + banana | 650 | 25 g | 105 g | 13 g |
# | Mid-morning | 40 g roasted chana + 200 g curd | 250 | 14 g | 34 g | 6 g |
# | Lunch | 300 g rice + 200 g dal + vegetables + 150 g curd + 10 g oil | 760 | 28 g | 120 g | 19 g |
# | Pre-workout | Banana + 40 g peanuts | 330 | 9 g | 38 g | 17 g |
# | Post-workout | 300 ml milk + 50 g soy chunks | 335 | 31 g | 24 g | 9 g |
# | Dinner | 3 chapatis + 150 g paneer/soy curry + vegetables | 560 | 29 g | 60 g | 22 g |
# | **Total** | | **~2,885** | **~136 g** | **~381 g** | **~86 g** |
#
# ## Day 5 — Thursday 🟢 Vegetarian
#
# | Meal | Foods & quantity | kcal | Protein | Carbs | Fat |
# |---|---|---:|---:|---:|---:|
# | Breakfast | 3 dosa + 250 g sambar + 250 ml milk + banana | 650 | 24 g | 101 g | 16 g |
# | Mid-morning | 30 g peanuts + 200 g curd | 285 | 12 g | 17 g | 19 g |
# | Lunch | 300 g rice + 200 g rajma/dal + vegetables + 150 g curd | 735 | 27 g | 121 g | 15 g |
# | Pre-workout | 2 bananas + 30 g roasted chana | 275 | 7 g | 55 g | 3 g |
# | Post-workout | 300 ml milk + 50 g soy chunks | 335 | 31 g | 24 g | 9 g |
# | Dinner | 3 chapatis + 200 g dal + 150 g vegetables + 100 g curd | 590 | 28 g | 88 g | 13 g |
# | **Total** | | **~2,870** | **~129 g** | **~406 g** | **~75 g** |
#
# ## Day 6 — Friday 🔴 Non-Vegetarian
#
# | Meal | Foods & quantity | kcal | Protein | Carbs | Fat |
# |---|---|---:|---:|---:|---:|
# | Breakfast | 4 idlis + 3 eggs + 200 g sambar + banana | 700 | 33 g | 103 g | 20 g |
# | Mid-morning | 250 ml milk + 30 g peanuts | 325 | 14 g | 20 g | 21 g |
# | Lunch | 300 g rice + 150 g fish + 200 g vegetables + 150 g curd | 750 | 43 g | 106 g | 18 g |
# | Pre-workout | Banana + 2 bread slices + 15 g peanut butter | 320 | 9 g | 51 g | 10 g |
# | Post-workout | 300 ml milk + 2 eggs | 275 | 20 g | 15 g | 15 g |
# | Dinner | 3 chapatis + 100 g chicken + vegetables | 530 | 34 g | 62 g | 14 g |
# | **Total** | | **~2,900** | **~153 g** | **~357 g** | **~98 g** |
#
# ## Day 7 — Saturday 🔴 Non-Vegetarian
#
# | Meal | Foods & quantity | kcal | Protein | Carbs | Fat |
# |---|---|---:|---:|---:|---:|
# | Breakfast | 3 dosa + 3 eggs + 250 g sambar + banana | 720 | 32 g | 101 g | 23 g |
# | Mid-morning | 250 ml milk + 30 g peanuts | 325 | 14 g | 20 g | 21 g |
# | Lunch | 300 g rice + 150 g chicken + vegetables + 150 g curd | 790 | 48 g | 105 g | 21 g |
# | Pre-workout | Banana + 40 g roasted chana | 260 | 8 g | 48 g | 4 g |
# | Post-workout | 300 ml milk + 2 eggs | 275 | 20 g | 15 g | 15 g |
# | Dinner | 3 chapatis + 100 g fish + vegetables + 100 g curd | 545 | 35 g | 65 g | 14 g |
# | **Total** | | **~2,915** | **~157 g** | **~354 g** | **~98 g** |
#
# # 3. Daily Summary
#
# | Day | Type | Calories | Protein | Carbs | Fat | Prep time |
# |---|---|---:|---:|---:|---:|---:|
# | Sunday | Veg | ~2,950 | ~125 g | ~401 g | ~93 g | 45–60 min |
# | Monday | Veg | ~2,930 | ~127 g | ~420 g | ~84 g | 30–45 min |
# | Tuesday | Non-veg | ~2,970 | ~160 g | ~347 g | ~105 g | 45–60 min |
# | Wednesday | Veg | ~2,885 | ~136 g | ~381 g | ~86 g | 40–50 min |
# | Thursday | Veg | ~2,870 | ~129 g | ~406 g | ~75 g | 40–50 min |
# | Friday | Non-veg | ~2,900 | ~153 g | ~357 g | ~98 g | 45–60 min |
# | Saturday | Non-veg | ~2,915 | ~157 g | ~354 g | ~98 g | 45–60 min |
#
# # 4. Weekly Grocery List
#
# Approximate weekly quantities:
#
# - Rice: 3.5–4 kg
# - Oats: 500 g
# - Wheat flour/atta: 1.5 kg
# - Idli/dosa batter: 2–2.5 kg
# - Bread: 2 loaves
# - Roasted chana: 500 g
# - Eggs: 12–15
# - Chicken: 750 g–1 kg
# - Fish: 500–750 g
# - Soy chunks: 500 g
# - Toor dal: 750 g
# - Other dal/rajma: 750 g
# - Peanuts: 750 g
# - Milk: 4–5 L
# - Curd: 2–2.5 kg
# - Paneer: 200–250 g
# - Bananas: 14–18
# - Seasonal fruit: 1–2 kg
# - Vegetables: 3–4 kg
# - Cooking oil: 300–400 ml
#
# Estimated weekly food budget: **~₹2,950–3,250**, or approximately **₹11,800–13,000/month**.
#
# To stay under ₹12,000, prioritize soy chunks, dal, eggs, local fish, seasonal fruits, homemade curd, and bulk staples.
#
# # 5. Meal Prep Strategy
#
# Prepare rice, sambar, dal, soy chunks, boiled eggs, chopped vegetables, and roasted peanuts/chana in batches. Pack rice + dal/sambar + vegetables + curd or rice + chicken/fish + vegetables for work. Refrigerate cooked food promptly in airtight containers.
#
# Quick meals include oats + milk + banana + peanuts, dosa + sambar + soy curry, rice + dal + curd, and chapati + leftover chicken.
#
# # 6. Workout Nutrition
#
# Good pre-workout options 60–120 minutes before training:
#
# - Banana + bread + peanut butter
# - 2 bananas + roasted chana
# - 3 idlis + sambar
# - 2 dosa + sambar
#
# Post-workout options within roughly 1–2 hours:
#
# - Milk + soy chunks
# - Rice + dal + curd
# - Eggs + milk
# - Rice + chicken/fish
#
# Aim for roughly **2.5–3.5 L water/day**, adjusting for heat, sweat, and training.
#
# # 7. Weight Tracking & Adjustments
#
# Weigh yourself in the morning after using the bathroom and before eating or drinking. Use the same scale under similar conditions. Calculate the 7-day average.
#
# If the weekly average does not rise for **2–3 consecutive weeks**, add **150–200 kcal/day**.
#
# If weight consistently increases faster than about **0.5 kg/week**, reduce approximately **150–200 kcal/day**.
#
# A useful target is around **0.2–0.4 kg/week**.
#
# # 8. Budget Check
#
# The plan sits close to the ₹12,000/month limit. Expensive foods such as paneer, premium fish, whey, almonds, walnuts, protein bars, and mass gainers are unnecessary. Use soy chunks, dal, chana, peanuts, eggs, milk/curd, chicken, and local fish as the main affordable protein sources.
#
# # 9. Important Notes
#
# Calorie and macro values are estimates. Actual values vary by brand, cooking method, portion size, oil usage, and preparation.
#
# This meal plan is general nutrition guidance and is not a substitute for individualized medical or clinical nutrition advice.
